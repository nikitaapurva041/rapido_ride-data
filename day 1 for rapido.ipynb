# %%
# import file
import pandas as pd

# %%
# load the file
df=pd.read_csv(r"C:\Users\VISHAL\Desktop\Python project\rapido data.csv")

# %%
# check the row of data
df.head()
# Out:
#       services         date     time ride_status                  source  \
# 0  cab economy  15-Jul-2024  30:40.5   completed         Balagere Harbor
# 1         auto   5-Jul-2024  36:51.5   completed  Basavanagudi 3rd Block
# 2         auto  23-Jul-2024  05:37.5   cancelled        Babusapalya Cove
# 3  cab economy  24-Jun-2024  45:10.5   completed       Mahadevapura Mews
# 4  cab economy  15-Jul-2024  26:44.5   completed         Ganganagar Cove
#
#                 destination  duration             ride_id  distance  \
# 0           Harohalli Nagar      39.0  RD3161218751875354     27.21
# 1      Bikasipura 1st Stage      89.0  RD8171514284594096     34.03
# 2         Kothaguda Terrace      25.0  RD9376481122237926     20.24
# 3            Kanakapura Arc      89.0  RD3676889143182765     31.17
# 4  Basaveshwaranagar Colony      95.0  RD6639410275948084     27.21
#
#    ride_charge  misc_charge  total_fare payment_method
# 0       764.83        31.51      796.34     Amazon Pay
# ...

# %%
# check row/column
df.shape
# Out:
# (50004, 13)

# %%
# check the column Name
df.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'ride_id', 'distance', 'ride_charge', 'misc_charge',
#        'total_fare', 'payment_method'],
#       dtype='str')

# %%
# check data types
df.dtypes
# Out:
# services              str
# date                  str
# time                  str
# ride_status           str
# source                str
# destination           str
# duration          float64
# ride_id               str
# distance          float64
# ride_charge       float64
# misc_charge       float64
# total_fare        float64
# payment_method        str
# dtype: object

# %%
# change the data type of date from str to date time
df['date']=pd.to_datetime(df['date'])
print(df['date'])
# Out:
# 0       2024-07-15
# 1       2024-07-05
# 2       2024-07-23
# 3       2024-06-24
# 4       2024-07-15
#            ...
# 49999   2024-08-07
# 50000          NaT
# 50001          NaT
# 50002          NaT
# 50003          NaT
# Name: date, Length: 50004, dtype: datetime64[us]

# %%
# check the data type
df.dtypes
# Out:
# services                     str
# date              datetime64[us]
# time                         str
# ride_status                  str
# source                       str
# destination                  str
# duration                 float64
# ride_id                      str
# distance                 float64
# ride_charge              float64
# misc_charge              float64
# total_fare               float64
# payment_method               str
# dtype: object

# %%
# change the time data type from str to datetime
df['time']=df.to_time(df["time"])
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    ]
# Out:
#   Cell In[17], line 373
#     ]
#     ^
# IndentationError: unexpected indent
